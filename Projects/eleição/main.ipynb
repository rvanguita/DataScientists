# %% [markdown]
# # [Dataset](https://dados.gov.br/)

# %% [markdown]
# Este arquivo contém o leiaute das tabelas existentes no repositório de dados eleitorais. Antes de
# trabalhar os dados é importante ler as seguintes considerações:
# - A codificação de caracteres dos arquivos é "Latin 1";
# - Os campos estão entre aspas e separados por ponto e vírgula, inclusive os campos numéricos;
# - Campos preenchidos com #NULO significam que a informação está em branco no banco de dados.
# O correspondente para #NULO nos campos numéricos é -1;
# - Campos preenchidos com #NE significam que naquele ano a informação não era registrada em
# banco de dados pelos sistemas eleitorais. O correspondente para #NE nos campos numéricos é -3;
# - O campo UF, além das unidades da federação, pode conter alguma das seguintes situações:
# o BR: quando se tratar de informação a nível nacional;
# o VT: quando se tratar de voto em trânsito;
# o ZZ: quando se tratar de Exterior.
# - Os arquivos estão em constante processo de atualização e aperfeiçoamento. Alguns arquivos podem
# estar em branco ou com mensagem de erro devido a indisponibilidade temporária na base de algum
# estado ou à inexistência daquele arquivo para a época pretendida.
#
#
# Agradecemos todas as críticas e sugestões recebidas de pesquisadores e usuários que estão
# colaborando para a melhoria na qualidade da prestação das informações. Em especial à Associação
# Brasileira de Ciência Política (ABCP)que, por meio de acordo de cooperação técnica firmado com o
# TSE, está auxiliando na verificação dos arquivos gerados e informando o TSE quanto às
# necessidades de dados dos pesquisadores.
# Qualquer sugestão ou dúvida deve ser encaminhad

# %% [markdown]
# | Variável                 | Descrição                                                                                                                                                                                                                                                                                                                                                                                            |
# |--------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | DT_GERACAO               | Data da extração dos dados para geração do arquivo.                                                                                                                                                                                                                                                                                                                                                   |
# | HH_GERACAO               | Hora da extração dos dados para geração do arquivo com base no horário de Brasília.                                                                                                                                                                                                                                                                                                                   |
# | AA_ELEICAO               | Ano de referência da eleição para geração do arquivo. Observação: para eleições suplementares, o ano de referência da eleição é o da eleição ordinária correspondente. Por exemplo: em 2016 houve eleições ordinárias. Após a data desta eleição ordinária e antes da próxima, houve eleições suplementares em 2017, 2018 e 2019. As informações dessas eleições suplementares estarão divulgadas no arquivo gerado para as Eleições 2016. |
# | CD_ELEICAO               | Código identificador da eleição.                                                                                                                                                                                                                                                                                                                                                                      |
# | NM_ELEICAO               | Descrição ou nome da eleição.                                                                                                                                                                                                                                                                                                                                                                         |
# | SG_UF                    | Sigla da unidade da federação onde ocorreu a pesquisa eleitoral realizada.                                                                                                                                                                                                                                                                                                                            |
# | SG_UE                    | Sigla da unidade eleitoral de abrangência da pesquisa eleitoral realizada. Pode assumir os valores: - sigla da UF: quando a abrangência da pesquisa realizada é estadual; e - código do município: quando a abrangência da pesquisa realizada é municipal.                                                                                                                                             |
# | NM_UE                    | Nome da unidade eleitoral de abrangência da pesquisa eleitoral realizada. Pode assumir os valores: - nome da UF: quando a abrangência da pesquisa realizada é estadual; e - nome do município: quando a abrangência da pesquisa realizada é municipal.                                                                                                                                                |
# | NR_PROTOCOLO_REGISTRO     | Número do protocolo gerado no ato do registro da pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                                  |
# | DT_REGISTRO              | Data do registro da pesquisa eleitoral junto ao TSE.                                                                                                                                                                                                                                                                                                                                                  |
# | ST_PESQUISA_PROPRIA      | Situação que indica se a pesquisa eleitoral foi realizada pela própria empresa. Pode assumir os valores: - N: Não (empresa diferente); e - S: Sim (própria empresa).                                                                                                                                                                                                                                  |
# | NR_CNPJ_EMPRESA          | CNPJ da empresa contratada para realizar a pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                                        |
# | NM_EMPRESA               | Nome da empresa contratada para realizar a pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                                        |
# | NM_EMPRESA_FANTASIA      | Nome fantasia da empresa contratada para realizar a pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                               |
# | DS_CARGO                 | Descrição do(s) cargo(s) eleitoral relacionado(s) à pesquisa eleitoral. Caso a pesquisa seja realizada para mais de um cargo, estes estão separados por vírgula.                                                                                                                                                                                                                                      |
# | DT_INICIO_PESQUISA       | Data de início de realização da pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                                                   |
# | DT_FIM_PESQUISA          | Data fim de realização da pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                                                          |
# | DT_DIVULGACAO            | Data a partir da qual a empresa pode publicar o resultado da pesquisa eleitoral nos meios de comunicação.                                                                                                                                                                                                                                                                                              |
# | QT_ENTREVISTADO          | Quantidade de pessoas entrevistadas na pesquisa eleitoral realizada.                                                                                                                                                                                                                                                                                                                                  |
# | CD_CONRE                 | Código de registro, junto ao CONRE - Conselho Regional de Estatística, do estatístico responsável pela pesquisa eleitoral.                                                                                                                                                                                                                                                                              |
# | NM_ESTATISTICO_RESP      | Nome do estatístico responsável pela pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                                              |
# | VR_PESQUISA              | Valor, em reais (R$), do custo da pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                                                  |
# | DS_METODOLOGIA_PESQUISA  | Descrição da metodologia de pesquisa aplicada para a realização da pesquisa eleitoral.                                                                                                                                                                                                                                                                                                                 |
# | DS_PLANO_AMOSTRAL        | Descrição do plano amostral e ponderação aplicados à pesquisa eleitoral com relação ao sexo, idade, grau de instrução e nível econômico do entrevistado, bem como indicação do intervalo de confiança e da margem de erro utilizados.                                                                                                                                                                  |
# | DS_SISTEMA_CONTROLE      | Descrição do sistema interno de controle, verificação, conferência e fiscalização da coleta de dados e do trabalho de campo utilizados na pesquisa eleitoral.                                                                                                                                                                                                                                          |
# | DS_DADO_MUNICIPIO        | Complemento do registro da pesquisa com os dados relativos aos bairros abrangidos e, na ausência de delimitação do bairro, será identificada a área em que foi realizada a pesquisa eleitoral realizada, conforme §6º do art. 2º da Resolução TSE nº. 23.453/2015.                                                                                                                                     |

# %%
import pandas as pd

# %%
df = pd.read_csv('data/pesquisa_eleitoral_2024_SP.csv', encoding='ISO-8859-1', sep=';')
df
# Out:
#       DT_GERACAO HH_GERACAO  AA_ELEICAO  CD_ELEICAO                NM_ELEICAO  \
# 0     23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# 1     23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# 2     23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# 3     23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# 4     23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# ...          ...        ...         ...         ...                       ...
# 1256  23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# 1257  23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# 1258  23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# 1259  23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
# 1260  23/09/2024   01:01:44        2024          11  Eleições Municipais 2024
#
# ...

# %%
df.columns
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_ELEICAO', 'CD_ELEICAO', 'NM_ELEICAO',
#        'SG_UF', 'SG_UE', 'NM_UE', 'NR_PROTOCOLO_REGISTRO', 'DT_REGISTRO',
#        'ST_PESQUISA_PROPRIA', 'NR_CNPJ_EMPRESA', 'NM_EMPRESA',
#        'NM_EMPRESA_FANTASIA', 'DS_CARGO', 'DT_INICIO_PESQUISA',
#        'DT_FIM_PESQUISA', 'DT_DIVULGACAO', 'QT_ENTREVISTADO', 'CD_CONRE',
#        'NM_ESTATISTICO_RESP', 'VR_PESQUISA', 'DS_METODOLOGIA_PESQUISA',
#        'DS_PLANO_AMOSTRAL', 'DS_SISTEMA_CONTROLE', 'DS_DADO_MUNICIPIO'],
#       dtype='object')

# %%
df.shape
# Out:
# (1261, 26)

# %%
for idx, city in enumerate(df['NM_UE']):
    if city == 'CAMPINAS' and df['DS_CARGO'][idx] == 'Prefeito':
        print(df['NM_ESTATISTICO_RESP'][idx], df['DS_CARGO'][idx])
# Out:
# Vera Lúcia Candiani Prefeito
# Vera Lúcia Candiani Prefeito
# Vera Lúcia Candiani Prefeito
# Isabela Zara Cremoneze Prefeito
# Andrei Camilo dos Santos Prefeito
# Luan Francisco da Silva Prefeito
# GUILHERME COELHO NEVES Prefeito
# Tatiani Cristina Ara Prefeito
# GUILHERME COELHO NEVES Prefeito
# Tatiani Cristina Ara Prefeito
