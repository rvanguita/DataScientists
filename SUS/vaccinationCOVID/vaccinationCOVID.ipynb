# %%
import requests
import pandas as pd
import json
from requests.auth import HTTPBasicAuth

# %%
# API = "https://imunizacao-es.saude.gov.br/_search?scroll=1m"
# username = "imunizacao_public"
# password = "qlto5t&7r_@+#Tlstigi"

# %%
url = "https://imunizacao-es.saude.gov.br/_search?scroll=1m"

headers = {
  'Authorization': 'Basic aW11bml6YWNhb19wdWJsaWM6cWx0bzV0JjdyX0ArI1Rsc3RpZ2k=',
  'Content-Type': 'application/json'
}

# %%
payload = json.dumps({
  "size": 10000
})

# %%
dataSUS = requests.request("GET", url, headers=headers, data=payload)

# %%
dataSUS.json()
# Out:
# {'_scroll_id': 'FGluY2x1ZGVfY29udGV4dF91dWlkDnF1ZXJ5VGhlbkZldGNoHhY5VDJCckZvOVFyMm03ZHRPNjF4QUdBAAAAAH--...-...',
#  'took': 349,
#  'timed_out': False,
#  '_shards': {'total': 30, 'successful': 30, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 545389633, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': '16f07e59-3097-4410-8d49-f61f4bee90f6-i0b0',
#     '_score': 1.0,
#     '_source': {'vacina_grupoAtendimento_nome': 'Pessoas de 80 anos ou mais',
#      'vacina_codigo': '103',
#      'paciente_dataNascimento': '1937-09-18',
#      'ds_condicao_maternal': None,
#      'paciente_endereco_nmPais': 'BRASIL',
# ...

# %%
vaccinationSUS = dataSUS.json()

# %%
dfVaccination = pd.json_normalize(vaccinationSUS['hits']['hits'])

# %%
len(dfVaccination)
# Out:
# 10000

# %%
dfVaccination.isnull().sum()
# Out:
# _index                                                 0
# _type                                                  0
# _id                                                    0
# _score                                                 0
# _source.vacina_grupoAtendimento_nome                  12
# _source.vacina_codigo                                  0
# _source.paciente_dataNascimento                        0
# _source.ds_condicao_maternal                        8751
# _source.paciente_endereco_nmPais                       0
# _source.paciente_racaCor_valor                         0
# _source.sistema_origem                                 0
# _source.paciente_id                                    0
# _source.paciente_endereco_uf                           0
# _source.paciente_idade                                 0
# _source.paciente_endereco_cep                          0
# _source.estabelecimento_valor                          0
# ...
